# %%
import pandas as pd

# %%
df = pd.DataFrame([[1, 2], [3, 4], [5, 6]], columns=['x', 'y',], index=['a', 'b', 'c'])

# %%
df
# Out:
#    x  y
# a  1  2
# b  3  4
# c  5  6

# %%
df.head()
# Out:
#    x  y
# a  1  2
# b  3  4
# c  5  6

# %%
df.tail()
# Out:
#    x  y
# a  1  2
# b  3  4
# c  5  6

# %%
df
# Out:
#    x  y
# a  1  2
# b  3  4
# c  5  6

# %%
df.head(1)
# Out:
#    x  y
# a  1  2

# %%
df.tail(1)
# Out:
#    x  y
# c  5  6

# %%
coffee = pd.read_csv('warmup-data/coffee.csv')

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
results = pd.read_parquet('data/results.parquet')

# %%
results.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA             None   17.0   True  None
# 1           1  FRA   Jean Montariol    NaN  False  None
# 2           1  FRA             None   32.0   True  None
# 3           1  FRA  Jeanne Vaussard    8.0   True  None
# 4           1  FRA  Jacques Brugnon    4.0  False  None

# %%
coffee.sort_values('Units Sold', ascending=False)
# Out:
#           Day Coffee Type  Units Sold
# 10   Saturday    Espresso          45
# 8      Friday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 4   Wednesday    Espresso          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 9      Friday       Latte          35
# 2     Tuesday    Espresso          30
# 7    Thursday       Latte          30
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 3     Tuesday       Latte          20
# 1      Monday       Latte          15

# %%
bios = pd.read_csv('data/bios.csv')

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
bios.loc[bios['born_country'] == 'PAK', ['name', 'born_city']]
# Out:
#                          name   born_city
# 288            Mohammed Sleem      Multan
# 1046              Farjad Saif     Karachi
# 3991               Boy Murphy      Murree
# 4800              Javid Aslam  Faisalabad
# 4880                 Asif Dar      Quetta
# ...                       ...         ...
# 128770          Najma Parveen  Faisalabad
# 128771          Minhal Sohail     Karachi
# 132543            Mehboob Ali       Kasur
# 132545  Ghulam Mustafa Bashir       Okara
# 142245            Talha Talib  Gujranwala
#
# [187 rows x 2 columns]

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios.loc[bios['name'].str.contains('saqlain|zain' , case=False)]
# Out:
#         athlete_id                           name   born_date  \
# 5275          5294                 Zaina Kapepula  1975-08-14
# 12794        12864             Jean-Yves Touzaint  1948-10-08
# 12795        12865               Thierry Touzaint  1953-12-26
# 16297        16412                Safarrudin Zain  1938-03-22
# 19419        19558        Khair-ud-Din bin Zainal  1946-11-21
# 19459        19598            Azaari Mohamed Zain  1952-12-11
# 19467        19606  Nor Saiful Zaini Nasir-ud-Din  1966-03-27
# 29765        29990              Georges Mauvezain  1878-02-27
# 50577        50936           Ana Carolina Itzaina  1979-05-14
# 72835        73389    Zain-ud-Din bin Abdul Wahab  1948-05-14
# 89968        90688               Nicolas Touzaint  1980-05-10
# 112653      113931               Muhammad Saqlain  1978-02-23
# 118383      120093                    Zain Shaito  1990-10-19
# 121398      123383                     Salma Zain  1990-04-14
#
# ...

# %%
bios.loc[bios['name'].str.contains('saqlain', case=False), 'NOC'] = 'ITA'

# %%
bios.loc[bios['name'].str.contains('saqlain' , case=False)]
# Out:
#         athlete_id              name   born_date born_city born_region  \
# 112653      113931  Muhammad Saqlain  1978-02-23    Lahore      Punjab
#
#        born_country  NOC  height_cm  weight_kg died_date
# 112653          PAK  ITA      178.0       64.0       NaN

# %%
bios.loc[bios['name'].str.contains('khalid' , case=False)]
# Out:
#         athlete_id                       name   born_date          born_city  \
# 4018          4032           Khalid Al-Karkhi  1940-08-15            Baghdad
# 4493          4508             Khalid Rahilou  1966-06-19                NaN
# 16440        16556             Khalid Shebani         NaN                NaN
# 19853        19993              Khalid Bashir  1968-02-14         Faisalabad
# 19854        19994               Khalid Hamid  1962-11-18         Gujranwala
# 19855        19995             Khalid Mahmood  1941-12-28             Jhelum
# 19856        19996            Muhammad Khalid  1973-03-18                NaN
# 19884        20024             Khalid Mahmood  1969-03-10                NaN
# 21213        21361        Abdul Rahman Khalid  1966-01-17                NaN
# 24559        24748            Khalid Gadallah  1958-10-24  Al-Qahira (Cairo)
# 26252        26445             Khalid El-Bied  1955-08-24              Rabat
# ...

# %%
bios.loc[bios['name'].str.contains('butt' , case=False)]
# Out:
#         athlete_id                   name   born_date          born_city  \
# 3928          3942          Paul Buttimer  1966-07-02                NaN
# 13738        13823           Paul Carbutt  1950-07-04           Solihull
# 19836        19975          Jahangir Butt  1943-04-17         Gujranwala
# 21944        22100      Harry Butterworth  1867-11-22            Dunedin
# 35499        35777        Jim Butterfield  1950-09-01           Hamilton
# 41957        42280              John Butt  1850-10-30       South Witham
# 46464        46812           Serge Buttet  1954-12-14   Romans-sur-Isère
# 54844        55238          Gaston Butter  1888-03-14              Rongy
# 56056        56454       Abdul Ghani Butt  1939-01-15         Gujranwala
# 56057        56455    Muhammad Iqbal Butt  1929-12-11                NaN
# 56058        56456     Muhammad Naqi Butt  1919-02-14                NaN
# 57754        58162             Alan Butts  1940-04-11         Birmingham
# ...

# %%
bios.loc[bios['NOC'] == 'pakistan']
# Out:
# Empty DataFrame
# Columns: [athlete_id, name, born_date, born_city, born_region, born_country, NOC, height_cm, weight_kg, died_date]
# Index: []
